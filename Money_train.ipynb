# %%
#import thư viện
import numpy as np
from os import listdir
from numpy import asarray, save
from keras.utils import load_img, img_to_array, to_categorical
from keras.models import Sequential, load_model
from keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D,Normalization,LeakyReLU
from keras.optimizers import Adam
from keras.losses import categorical_crossentropy
import matplotlib.pyplot as plt
from keras.utils.image_utils import img_to_array

# %%
#load folder datasets
folder = '/content/drive/MyDrive/money/'
#tiến hành tiền xử lý dữ liệu
photos, labels = list(), list()
for file in listdir(folder):
  output = 0.0
  if file.startswith('5000 '):
    output = 1.0
  if file.startswith('10000 '):
    output = 2.0
  if file.startswith('20000 '):
    output = 3.0
  if file.startswith('50000 '):
    output = 4.0
  if file.startswith('100000 '):
    output = 5.0
  if file.startswith('500000 '):
    output = 6.0

  img =load_img(folder+file,target_size=(100,200))
  photo = img_to_array(img)
  photos.append(photo)
  labels.append(output)
photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)
# Out:
# (90, 100, 200, 3) (90,)

# %%
# lưu dữ liệu vừa xử lý
save('tien_hinh_hoc.npy',photos)
save('tien_ten_hoc.npy',labels)

# %%
# tạo dữ liệu train
x_train = np.load('/content/tien_hinh_hoc.npy')
y_train = np.load('/content/tien_ten_hoc.npy')

# %%
x_train = x_train.astype('float32')/255
y_train = to_categorical(y_train,10)

# %%
#32 lan tich chap
model = Sequential()
model.add(Conv2D(32,kernel_size = (3,3),activation = 'relu',input_shape=(100,200,3),padding='Same'))
model.add(MaxPooling2D((2,2),padding='same'))
model.add(Dropout(0.25))

#64 lan tich chap
model.add(Conv2D(64,(3,3),activation ='relu',padding ='same'))
model.add(MaxPooling2D((2,2),padding='same'))
model.add(Dropout(0.25))

#128 lan tich chap
model.add(Conv2D(128,(3,3),activation ='relu',padding ='same'))
model.add(MaxPooling2D((2,2),padding='same'))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(64,activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(10,activation='softmax'))
# train mô hình
model.compile(loss = categorical_crossentropy,optimizer = Adam(),metrics=['accuracy'])
model.summary()
train = model.fit(x_train,y_train,batch_size=32,epochs = 50,verbose = 1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 100, 200, 32)      896
#
#  max_pooling2d_3 (MaxPooling  (None, 50, 100, 32)      0
#  2D)
#
#  dropout_4 (Dropout)         (None, 50, 100, 32)       0
#
#  conv2d_4 (Conv2D)           (None, 50, 100, 64)       18496
#
#  max_pooling2d_4 (MaxPooling  (None, 25, 50, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 25, 50, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 25, 50, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 13, 25, 128)      0
#  2D)
#
#  dropout_6 (Dropout)         (None, 13, 25, 128)       0
#
#  flatten_1 (Flatten)         (None, 41600)             0
#
#  dense_2 (Dense)             (None, 64)                2662464
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 2,756,362
# Trainable params: 2,756,362
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 3/3 [==============================] - 2s 281ms/step - loss: 3.3704 - accuracy: 0.0889
# Epoch 2/50
# 3/3 [==============================] - 0s 34ms/step - loss: 2.2561 - accuracy: 0.1333
# Epoch 3/50
# 3/3 [==============================] - 0s 36ms/step - loss: 2.1601 - accuracy: 0.1333
# Epoch 4/50
# 3/3 [==============================] - 0s 40ms/step - loss: 2.0114 - accuracy: 0.2444
# Epoch 5/50
# 3/3 [==============================] - 0s 41ms/step - loss: 2.0021 - accuracy: 0.2000
# Epoch 6/50
# 3/3 [==============================] - 0s 37ms/step - loss: 1.9471 - accuracy: 0.2000
# Epoch 7/50
# 3/3 [==============================] - 0s 34ms/step - loss: 1.9076 - accuracy: 0.1889
# Epoch 8/50
# 3/3 [==============================] - 0s 37ms/step - loss: 1.7311 - accuracy: 0.3222
# Epoch 9/50
# 3/3 [==============================] - 0s 36ms/step - loss: 1.6325 - accuracy: 0.3889
# Epoch 10/50
# 3/3 [==============================] - 0s 36ms/step - loss: 1.5976 - accuracy: 0.2444
# Epoch 11/50
# 3/3 [==============================] - 0s 35ms/step - loss: 1.3980 - accuracy: 0.4444
# Epoch 12/50
# 3/3 [==============================] - 0s 34ms/step - loss: 1.3133 - accuracy: 0.4667
# Epoch 13/50
# 3/3 [==============================] - 0s 34ms/step - loss: 1.2003 - accuracy: 0.4556
# Epoch 14/50
# 3/3 [==============================] - 0s 35ms/step - loss: 1.2067 - accuracy: 0.5000
# Epoch 15/50
# 3/3 [==============================] - 0s 35ms/step - loss: 1.1541 - accuracy: 0.5111
# Epoch 16/50
# 3/3 [==============================] - 0s 37ms/step - loss: 0.9837 - accuracy: 0.6111
# Epoch 17/50
# 3/3 [==============================] - 0s 40ms/step - loss: 0.9785 - accuracy: 0.5889
# Epoch 18/50
# 3/3 [==============================] - 0s 36ms/step - loss: 0.8586 - accuracy: 0.7111
# Epoch 19/50
# 3/3 [==============================] - 0s 40ms/step - loss: 0.6626 - accuracy: 0.8000
# Epoch 20/50
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7066 - accuracy: 0.6667
# Epoch 21/50
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6521 - accuracy: 0.7333
# Epoch 22/50
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5183 - accuracy: 0.8111
# Epoch 23/50
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5354 - accuracy: 0.8333
# Epoch 24/50
# 3/3 [==============================] - 0s 37ms/step - loss: 0.4026 - accuracy: 0.8556
# Epoch 25/50
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3516 - accuracy: 0.9111
# Epoch 26/50
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2971 - accuracy: 0.9222
# Epoch 27/50
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3729 - accuracy: 0.8778
# Epoch 28/50
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3403 - accuracy: 0.8778
# Epoch 29/50
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2298 - accuracy: 0.9333
# Epoch 30/50
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2584 - accuracy: 0.9000
# Epoch 31/50
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2281 - accuracy: 0.9000
# Epoch 32/50
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1609 - accuracy: 0.9556
# Epoch 33/50
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1919 - accuracy: 0.9111
# Epoch 34/50
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1844 - accuracy: 0.9111
# Epoch 35/50
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1244 - accuracy: 0.9556
# Epoch 36/50
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1732 - accuracy: 0.9111
# Epoch 37/50
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1378 - accuracy: 0.9556
# Epoch 38/50
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1261 - accuracy: 0.9556
# Epoch 39/50
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1279 - accuracy: 0.9556
# Epoch 40/50
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1825 - accuracy: 0.9222
# Epoch 41/50
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1340 - accuracy: 0.9333
# Epoch 42/50
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2126 - accuracy: 0.9222
# Epoch 43/50
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1905 - accuracy: 0.9222
# Epoch 44/50
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2013 - accuracy: 0.9444
# Epoch 45/50
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1265 - accuracy: 0.9667
# Epoch 46/50
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1530 - accuracy: 0.9444
# Epoch 47/50
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1121 - accuracy: 0.9667
# Epoch 48/50
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1690 - accuracy: 0.9889
# Epoch 49/50
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0519 - accuracy: 0.9889
# Epoch 50/50
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0550 - accuracy: 0.9889

# %%
#lưu mô hình vừa train
model.save('hoc_hinh_tien.h5')

# %%
model5=load_model('/content/drive/MyDrive/hoc_hinh_tien.h5')

# %%
vat = {1: '5000',2:'10000', 3:'20000', 4:'50000', 5:'100000', 6:'500000' }
img = load_img("/content/drive/MyDrive/tien5k.jpg",target_size=(100,200))
plt.imshow(img)
img = img_to_array(img)
img=img.reshape(1,100,200,3)
img = img.astype('float32')
img =img/255
result  = np.argmax(model.predict(img),axis=1)
vat[result[0]]
# Out:
# 1/1 [==============================] - 0s 183ms/step
# '5000'

# %%
img = load_img("/content/drive/MyDrive/download.jpg",target_size=(100,200))
plt.imshow(img)
img = img_to_array(img)
img=img.reshape(1,100,200,3)
img = img.astype('float32')
img =img/255
result  = np.argmax(model.predict(img),axis=1)
vat[result[0]]
# Out:
# 1/1 [==============================] - 0s 18ms/step
# '500000'
